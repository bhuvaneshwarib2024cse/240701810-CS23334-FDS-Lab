# %%
import numpy as np
array=np.random.randint(1,100,16) # randomly generate 16 numbers between 1 to 100
array
# Out:
# array([83, 14, 83, 93, 89, 27, 26, 43, 71, 41, 43, 38, 50, 66, 96, 85],
#       dtype=int32)

# %%
array.mean()
# Out:
# np.float64(59.25)

# %%
np.percentile(array,25)
# Out:
# np.float64(40.25)

# %%
np.percentile(array,50)
# Out:
# np.float64(58.0)

# %%
np.percentile(array,75)
# Out:
# np.float64(83.5)

# %%
np.percentile(array,100)
# Out:
# np.float64(96.0)

# %%
def outDetection(array):
    sorted(array)
    Q1,Q3=np.percentile(array,[25,75])
    IQR=Q3-Q1
    lr=Q1-(1.5*IQR)
    ur=Q3+(1.5*IQR)
    return lr,ur
lr,ur=outDetection(array)
lr,ur
# Out:
# (np.float64(-24.625), np.float64(148.375))

# %%
import seaborn as sns
# %matplotlib inline
sns.displot(array)

# %%
sns.distplot(array)
# Out:
# C:\Users\bhuvi\AppData\Local\Temp\ipykernel_6288\1133588802.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(array)
# <Axes: ylabel='Density'>

# %%
new_array=array[(array>lr) & (array<ur)]
new_array
# Out:
# array([83, 14, 83, 93, 89, 27, 26, 43, 71, 41, 43, 38, 50, 66, 96, 85],
#       dtype=int32)

# %%
sns.displot(new_array)

# %%
lr1,ur1=outDetection(new_array)
lr1,ur1
# Out:
# (np.float64(-55.125), np.float64(147.875))

# %%
final_array=new_array[(new_array>lr1) & (new_array<ur1)]
final_array
# Out:
# array([74, 69, 58, 66,  7, 21, 21, 71, 76, 22, 20, 90, 55, 99, 54, 16],
#       dtype=int32)

# %%
sns.distplot(final_array)
# Out:
# C:\Users\bhuvi\AppData\Local\Temp\ipykernel_7776\209491988.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(final_array)
# <Axes: ylabel='Density'>
